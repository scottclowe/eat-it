# %%
import sklearn
import pandas as pd
import numpy as np
import datetime

# %%
from IPython.display import HTML
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/backends/backend_gtk3agg.py:18: UserWarning: The Gtk3Agg backend is known to not work on Python 3.x with pycairo. Try installing cairocffi.
#   "The Gtk3Agg backend is known to not work on Python 3.x with pycairo. "

# %%
import holoviews as hv
# %load_ext holoviews.ipython
# %output holomap='widgets'

# %%
# %matplotlib inline

# %%
RMSE_baseline = 1929245.11374

# %%
pred_100 = 4453532.6
pred_075 = 3340149.4499999997
pred_050 = 2226766.3
pred_125 = 5566915.75

# %%
pred_dict = {1.00: pred_100,
             0.75: pred_075,
             0.50: pred_050,
             1.25: pred_125}

# %%
n_pub = 96

# %%
sublog = pd.read_csv('../submission_log.tsv', delimiter='\t')

# %%
sublog
# Out:
#              RMSE  factor    uid1    uid2                          label
# 0   1929245.11374    1.00    None    None                       baseline
# 1   1918277.94518    0.75   -2679   -2244        1st youngest and rarest
# 2   1933235.98790    0.50   -2679    None                   1st youngest
# 3   1929245.11374    0.75  -84446   -6212    2nd youngest and 1st oldest
# 4   1929245.11374    0.75  -29949  -11153    3rd youngest and 2nd oldest
# 5   1930481.41222    0.75   -2134   -2141       4th youngest, 3rd oldest
# 6   1934693.87604    1.25    None   -2141                3rd oldest only
# 7   1927046.20844    0.75  -20626   -3482    5th youngest and 4th oldest
# 8   1931541.59395    0.50  -20626    None                   5th youngest
# 9   1942908.27493    0.75  -34091  -50168    6th youngest and 5th oldest
# 10  1922213.90904    1.25    None  -50168                     5th oldest
# 11  1929245.11374    0.75  -38773  -47636    7th youngest and 6th oldest
# 12  1930448.49578    0.75  -13389  -36810    8th youngest and 7th oldest
# 13  1934726.72024    1.25    None  -36810                     7th oldest
# 14  1929245.11374    0.75   -4549  -10340    9th youngest and 8th oldest
# 15  1929245.11374    0.75  -41573  -31267   10th youngest and 9th oldest
# 16  1929245.11374    0.75  -17314  -34259  11th youngest and 10th oldest
# 17  1935385.89494    0.75  -51130  -37719  12th youngest and 11th oldest
# 18  1937359.46151    0.75  -22033  -13993  13th youngest and 12th oldest
# 19  1929245.11374    0.75  -17785  -33570  14th youngest and 13th oldest
# 20  1923902.66989    0.75  -60043   -1769  15th youngest and 14th oldest
# 21  1930626.24027    0.75  -51130  -22033                Shouldn't be in
# 22  1931168.37310    1.25    None  -37719                    11th oldest
# 23  1927806.31646    1.25    None  -13993                    12th oldest
# 24  1925264.06415    0.50  -60043    None                  15th youngest
# 25  1929245.11374    0.75  -43710    -446  16th youngest and 15th oldest
# 26  1929245.11374    0.75  -28435  -56002  17th youngest and 16th oldest
# 27  1931904.53686    0.75  -59684   -2421  18th youngest and 17th oldest
# 28  1929245.11374    1.25    None   -2421                    17th oldest
# 29  1931563.76731    0.75  -85087  -19786  19th youngest and 18th oldest
# ..            ...     ...     ...     ...                            ...
# 52  1913125.37996    0.50  -79610    None                  33rd youngest
# 53  1929245.11374    0.75  -24305   -9202  34th youngest and 37th oldest
# 54  1929245.11374    0.75  -80903  -23421  35th youngest and 38th oldest
# 55  1929245.11374    0.75  -92026   -9628  36th youngest and 39th oldest
# 56  1929245.11374    0.75  -66905  -45139  38th youngest and 43rd oldest
# 57  1928932.92690    0.75  -72643  -41030  37th youngest and 41st oldest
# 58  1936237.75410    1.25    None  -41030                    41st oldest
# 59  1929245.11374    0.75  -47378  -27471  39th youngest and 44th oldest
# 60  1929245.11374    0.75   -1695  -26852  40th youngest and 45th oldest
# 61  1924468.02942    0.75   -8724  -45770  41st youngest and 46th oldest
# 62  1926393.81819    0.50   -8724    None                  41st youngest
# 63  1921399.87823    0.75  -94111  -70732  42nd youngest and 47th oldest
# 64  1920258.76755    0.50  -94111    None                  42nd youngest
# 65  1937502.16506    0.75  -77410   -4612  43rd youngest and 48th oldest
# 66  1921564.12044    1.25    None   -4612                    48th oldest
# 67  1929245.11374    0.75  -47047  -63980                160th and 217th
# 68  1936225.73127    0.75  -12114   -7655                115th and 192th
# 69  1929245.11374    1.25    None   -7655                          192th
# 70  1984612.05385    0.75  -39224  -32088                 152th and 95th
# 71  1929245.11374    1.25  -39224    None                          152th
# 72  1929245.11374    0.75  -52625    -927                 230th and 60th
# 73  1929245.11374    0.75  -70416   -3206                112th and 244th
# 74  1929245.11374    0.75   -2660   -7233                142th and 191th
# 75  1926830.73755    0.75   -8159  -33933                  84th and 91th
# 76  1929245.11374    0.50   -8159    None                           84th
# 77  1929245.11374    0.75  -34382   -3096                  98th and 85th
# 78  1925156.50233    0.75  -30359  -25615                200th and 267th
# 79  1927769.14260    0.50  -30359    None                          200th
# 80  1922901.30601    0.75  -62817  -13480                184th and 116th
# 81        0.00000    0.50    None  -13480                184th and 116th
#
# [82 rows x 5 columns]

# %%
st = '-20626'
li = np.any(np.concatenate((
            np.expand_dims(sublog['uid1'].values==st,1),
            np.expand_dims(sublog['uid2'].values==st,1)
        ),axis=1),axis=1)

# %%
li.shape
# Out:
# (82,)

# %%
factors = sublog[li]['factor'].values
y = sublog[li]['RMSE'].values

# %%
x = np.array([pred_dict[f] for f in factors])
print(x)
print(y)
# Out:
# [ 3340149.45  2226766.3 ]
# [ 1927046.20844  1931541.59395]

# %%
x = np.append(x, pred_100)
y = np.append(y, RMSE_baseline)

# %%
print(x)
print(y)
# Out:
# [ 3340149.45  2226766.3   4453532.6 ]
# [ 1927046.20844  1931541.59395  1929245.11374]

# %% [markdown]
# Let
#
# y := RMSE_LB
#
# x := revenue_predicted
#
# We want to fit the curve
#
# y^2 = ( c + (x-x0)^2 )/n
#
# where
#
# x0 is the revenue_actual
#
# n is the number of datapoints used for the leaderboard score
#
# c is the squared error of all n-1 other datapoints
#
# This is the same as fitting
#
# n.y^2 = x^2 - 2.x0.x + (x0^2 + c)
#
# Since we already know x^2
#
# n.y^2 - x^2 = - 2.x0.x + (x0^2 + c)

# %%
plt.plot(x,y**2*n_pub,'o')

# %%
plt.plot(x,y**2*n_pub-x**2,'o')

# %%
z = np.polyfit(x, y**2*n_pub, 2)

# %%
z
# Out:
# array([  9.99999999e-01,  -7.06253800e+06,   3.68930015e+14])

# %%
z = np.polyfit(x, y**2*n_pub-x**2, 1)

# %%
z
# Out:
# array([ -7.06253800e+06,   3.68930015e+14])

# %%
-0.5 * z[0]
# Out:
# 3531268.9998708637

# %%
p = np.poly1d(z)
plt.plot(x,y**2*n_pub-x**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')

# %%
sublog
# Out:
#              RMSE  factor    uid1    uid2                          label
# 0   1929245.11374    1.00    None    None                       baseline
# 1   1918277.94518    0.75   -2679   -2244        1st youngest and rarest
# 2   1933235.98790    0.50   -2679    None                   1st youngest
# 3   1929245.11374    0.75  -84446   -6212    2nd youngest and 1st oldest
# 4   1929245.11374    0.75  -29949  -11153    3rd youngest and 2nd oldest
# 5   1930481.41222    0.75   -2134   -2141       4th youngest, 3rd oldest
# 6   1934693.87604    1.25    None   -2141                3rd oldest only
# 7   1927046.20844    0.75  -20626   -3482    5th youngest and 4th oldest
# 8   1931541.59395    0.50  -20626    None                   5th youngest
# 9   1942908.27493    0.75  -34091  -50168    6th youngest and 5th oldest
# 10  1922213.90904    1.25    None  -50168                     5th oldest
# 11  1929245.11374    0.75  -38773  -47636    7th youngest and 6th oldest
# 12  1930448.49578    0.75  -13389  -36810    8th youngest and 7th oldest
# 13  1934726.72024    1.25    None  -36810                     7th oldest
# 14  1929245.11374    0.75   -4549  -10340    9th youngest and 8th oldest
# 15  1929245.11374    0.75  -41573  -31267   10th youngest and 9th oldest
# 16  1929245.11374    0.75  -17314  -34259  11th youngest and 10th oldest
# 17  1935385.89494    0.75  -51130  -37719  12th youngest and 11th oldest
# 18  1937359.46151    0.75  -22033  -13993  13th youngest and 12th oldest
# 19  1929245.11374    0.75  -17785  -33570  14th youngest and 13th oldest
# 20  1923902.66989    0.75  -60043   -1769  15th youngest and 14th oldest
# 21  1930626.24027    0.75  -51130  -22033                Shouldn't be in
# 22  1931168.37310    1.25    None  -37719                    11th oldest
# 23  1927806.31646    1.25    None  -13993                    12th oldest
# 24  1925264.06415    0.50  -60043    None                  15th youngest
# 25  1929245.11374    0.75  -43710    -446  16th youngest and 15th oldest
# 26  1929245.11374    0.75  -28435  -56002  17th youngest and 16th oldest
# 27  1931904.53686    0.75  -59684   -2421  18th youngest and 17th oldest
# 28  1929245.11374    1.25    None   -2421                    17th oldest
# 29  1931563.76731    0.75  -85087  -19786  19th youngest and 18th oldest
# ..            ...     ...     ...     ...                            ...
# 52  1913125.37996    0.50  -79610    None                  33rd youngest
# 53  1929245.11374    0.75  -24305   -9202  34th youngest and 37th oldest
# 54  1929245.11374    0.75  -80903  -23421  35th youngest and 38th oldest
# 55  1929245.11374    0.75  -92026   -9628  36th youngest and 39th oldest
# 56  1929245.11374    0.75  -66905  -45139  38th youngest and 43rd oldest
# 57  1928932.92690    0.75  -72643  -41030  37th youngest and 41st oldest
# 58  1936237.75410    1.25    None  -41030                    41st oldest
# 59  1929245.11374    0.75  -47378  -27471  39th youngest and 44th oldest
# 60  1929245.11374    0.75   -1695  -26852  40th youngest and 45th oldest
# 61  1924468.02942    0.75   -8724  -45770  41st youngest and 46th oldest
# 62  1926393.81819    0.50   -8724    None                  41st youngest
# 63  1921399.87823    0.75  -94111  -70732  42nd youngest and 47th oldest
# 64  1920258.76755    0.50  -94111    None                  42nd youngest
# 65  1937502.16506    0.75  -77410   -4612  43rd youngest and 48th oldest
# 66  1921564.12044    1.25    None   -4612                    48th oldest
# 67  1929245.11374    0.75  -47047  -63980                160th and 217th
# 68  1936225.73127    0.75  -12114   -7655                115th and 192th
# 69  1929245.11374    1.25    None   -7655                          192th
# 70  1984612.05385    0.75  -39224  -32088                 152th and 95th
# 71  1929245.11374    1.25  -39224    None                          152th
# 72  1929245.11374    0.75  -52625    -927                 230th and 60th
# 73  1929245.11374    0.75  -70416   -3206                112th and 244th
# 74  1929245.11374    0.75   -2660   -7233                142th and 191th
# 75  1926830.73755    0.75   -8159  -33933                  84th and 91th
# 76  1929245.11374    0.50   -8159    None                           84th
# 77  1929245.11374    0.75  -34382   -3096                  98th and 85th
# 78  1925156.50233    0.75  -30359  -25615                200th and 267th
# 79  1927769.14260    0.50  -30359    None                          200th
# 80  1922901.30601    0.75  -62817  -13480                184th and 116th
# 81        0.00000    0.50    None  -13480                184th and 116th
#
# [82 rows x 5 columns]

# %%
all_uids = np.union1d(sublog['uid1'].values, sublog['uid2'].values)
print(all_uids)
# Out:
# ['-10340' '-11153' '-12114' '-12177' '-1218' '-13389' '-13480' '-13863'
#  '-13993' '-16052' '-1695' '-17314' '-1769' '-17785' '-18041' '-19786'
#  '-20626' '-2134' '-2141' '-22033' '-22417' '-2244' '-23421' '-2421'
#  '-24305' '-25615' '-26474' '-2660' '-2679' '-26852' '-27471' '-27510'
#  '-28385' '-28435' '-29949' '-30045' '-30359' '-3096' '-31267' '-3206'
#  '-32088' '-32381' '-33570' '-33933' '-34091' '-34259' '-34382' '-3482'
#  '-36810' '-37719' '-3799' '-38773' '-39224' '-41030' '-41573' '-4158'
#  '-42216' '-43710' '-446' '-45139' '-4549' '-45770' '-4612' '-4622'
#  '-47047' '-47378' '-47636' '-48222' '-4899' '-50168' '-51130' '-52625'
#  '-52946' '-55024' '-56002' '-59684' '-60043' '-61180' '-61478' '-6212'
#  '-62154' '-62817' '-63980' '-66905' '-68272' '-68448' '-70377' '-70416'
#  '-70732' '-7233' '-72643' '-7655' '-77410' '-7889' '-79610' '-80903'
#  '-8159' '-84446' '-85087' '-8724' '-9202' '-92026' '-927' '-94111' '-9601'
#  '-9628' 'None']

# %%
# Can we really generalise from just two datapoints?
st = '-36810'
li = np.any(np.concatenate((
            np.expand_dims(sublog['uid1'].values==st,1),
            np.expand_dims(sublog['uid2'].values==st,1)
        ),axis=1),axis=1)
y = sublog[li]['RMSE'].values
if np.any(np.isclose(y,RMSE_baseline)):
    print('uid {} is not in public test'.format(st))
factors = sublog[li]['factor'].values
x = np.array([pred_dict[f] for f in factors])
x = np.append(x, pred_100)
y = np.append(y, RMSE_baseline)

# Redact x and y
x = x[1:]
y = y[1:]

z, residuals, rank, singular_values, rcond = np.polyfit(x, y**2*n_pub-x**2, 1, full=True)
p = np.poly1d(z)

x0 = -0.5 * z[0]
c = z[1] - x0**2
print('uid = ',st)
print('x0 = ',x0)
print('{},{}'.format(st,x0))
print('c  = ',c)
print('res = ',residuals)

plt.plot(x,y**2*n_pub-x**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')
plt.show()

plt.plot(x,y,'o')
plt.plot(xx,((p(xx) + xx**2)/n_pub)**0.5,'--',color='r')
plt.show()


# add back in
x = np.array([pred_dict[f] for f in factors])
x = np.append(x, pred_100)
y = sublog[li]['RMSE'].values
y = np.append(y, RMSE_baseline)

# Don't refit the model! Just plot!

plt.plot(x,y**2*n_pub-x**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')
plt.show()

plt.plot(x,y,'o')
plt.plot(xx,((p(xx) + xx**2)/n_pub)**0.5,'--',color='r')
plt.show()
# Out:
# uid =  -36810
# x0 =  4097082.00125
# -36810,4097082.001251276
# c  =  3.57183667024e+14
# res =  []

# %% [markdown]
# Yes, we can generalise from only the common datapoint, plus one general datapoint.
#
# The change in the estimated true revenue was 0.001, which is negligible.
# ```
# -36810,4097082.000192844
# -36810,4097082.001251276
# ```

# %%
st = '-62817'
# Automated method. Blindly uses all available records.
li = np.any(np.concatenate((
            np.expand_dims(sublog['uid1'].values==st,1),
            np.expand_dims(sublog['uid2'].values==st,1)
        ),axis=1),axis=1)
y = sublog[li]['RMSE'].values
if np.any(np.isclose(y,RMSE_baseline)):
    print('!!!')
    print('uid {} is not in public test'.format(st))
    print('!!!')
factors = sublog[li]['factor'].values
x = np.array([pred_dict[f] for f in factors])
x = np.append(x, pred_100)
y = np.append(y, RMSE_baseline)

z, residuals, rank, singular_values, rcond = np.polyfit(x, y**2*n_pub-x**2, 1, full=True)
p = np.poly1d(z)

x0 = -0.5 * z[0]
c = z[1] - x0**2
print('uid = ',st)
print('x0 = ',x0)
print('{},{}'.format(st,x0))
print('c  = ',c)
print('res = ',residuals)

plt.plot(x,y**2*n_pub-x**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')
plt.show()

plt.plot(x,y,'o')
plt.plot(xx,((p(xx) + xx**2)/n_pub)**0.5,'--',color='r')
plt.show()
# Out:
# uid =  -62817
# x0 =  2843304.999
# -62817,2843304.9990005777
# c  =  3.54717891126e+14
# res =  []

# %%
# Need to be able to find a datapoint from only some of its records
st = '-4612'
li = np.any(np.concatenate((
            np.expand_dims(sublog['uid1'].values==st,1),
            np.expand_dims(sublog['uid2'].values==st,1)
        ),axis=1),axis=1)
print(sublog[li])
# Out:
#              RMSE  factor    uid1   uid2                          label
# 65  1937502.16506    0.75  -77410  -4612  43rd youngest and 48th oldest
# 66  1921564.12044    1.25    None  -4612                    48th oldest

# %%
# Need to be able to find a datapoint from only some of its records
st = '-4612'

locs = [66]

print(sublog.iloc[locs])

if np.any(sublog.iloc[locs]['uid1'].values!=st and sublog.iloc[locs]['uid2'].values!=st):
    print('!!!')
    print('uid {} is not found in all the listed records'.format(st))
    print('!!!')

y = sublog.iloc[locs]['RMSE'].values
print(y)
if np.any(np.isclose(y,RMSE_baseline)):
    print('!!!')
    print('uid {} is not in public test'.format(st))
    print('!!!')
factors = sublog.iloc[locs]['factor'].values
x = np.array([pred_dict[f] for f in factors])
x = np.append(x, pred_100)
y = np.append(y, RMSE_baseline)

z, residuals, rank, singular_values, rcond = np.polyfit(x, y**2*n_pub-x**2, 1, full=True)
p = np.poly1d(z)

x0 = -0.5 * z[0]
c = z[1] - x0**2
print('uid = ',st)
print('x0 = ',x0)
print('{},{}'.format(st,x0))
print('c  = ',c)
print('res = ',residuals)

plt.plot(x,y**2*n_pub-x**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')
plt.show()

plt.plot(x,y,'o')
plt.plot(xx,((p(xx) + xx**2)/n_pub)**0.5,'--',color='r')
plt.show()
# Out:
#              RMSE  factor  uid1   uid2        label
# 66  1921564.12044    1.25  None  -4612  48th oldest
# [ 1921564.12044]
# uid =  -4612
# x0 =  6285388.00024
# -4612,6285388.000239364
# c  =  3.53955029846e+14
# res =  []

# %% [markdown]
# If we only changed an ID with another ID (but we know the actual revenue for the second one) we need to fit
#
# y^2 = ( c + (x-x0)^2 )/n
#
# where c = c' + (t-t0)^2.
#
# n.y^2 - x^2 = - 2.x0.x + (x0^2 + c' + (t-t0)^2)
#
# But since t is not constant,
#
# n.y^2 - x^2 - (t-t0)^2 = - 2.x0.x + (x0^2 + c')

# %%
# Need to be able to find a datapoint which only changes with another datapoint
st = '-77410'

#t0 = 3672426.9993131235 # true value for '-2679'
#t0 = 4690137.001184127 # true value for '-37719'
t0 = 6285388.000239364 # true value for '-4612'

li = np.any(np.concatenate((
            np.expand_dims(sublog['uid1'].values==st,1),
            np.expand_dims(sublog['uid2'].values==st,1)
        ),axis=1),axis=1)
y = sublog[li]['RMSE'].values
if np.any(np.isclose(y,RMSE_baseline)):
    print('!!!')
    print('uid {} is not in public test'.format(st))
    print('!!!')

factors = sublog[li]['factor'].values
x = np.array([pred_dict[f] for f in factors])
x = np.append(x, pred_100)
y = np.append(y, RMSE_baseline)
t = x

z, residuals, rank, singular_values, rcond = np.polyfit(x, y**2*n_pub-x**2-(t-t0)**2, 1, full=True)
p = np.poly1d(z)

x0 = -0.5 * z[0]
c = z[1] - x0**2
print('uid = ',st)
print('x0 = ',x0)
print('{},{}'.format(st,x0))
print('c  = ',c)
print('res = ',residuals)

plt.plot(x,y**2*n_pub-x**2-(t-t0)**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')
plt.show()

plt.plot(x,y,'o')
plt.plot(xx,((p(xx) + xx**2 + (xx-t0)**2)/n_pub)**0.5,'--',color='r')
plt.show()
# Out:
# uid =  -77410
# x0 =  2884765.99896
# -77410,2884765.998955302
# c  =  3.51494001197e+14
# res =  []

# %%
st = '-2679'
# This is what things look like when they go wrong
li = np.any(np.concatenate((
            np.expand_dims(sublog['uid1'].values==st,1),
            np.expand_dims(sublog['uid2'].values==st,1)
        ),axis=1),axis=1)
y = sublog[li]['RMSE'].values
if np.any(np.isclose(y,RMSE_baseline)):
    print('uid {} is not in public test'.format(st))
factors = sublog[li]['factor'].values
x = np.array([pred_dict[f] for f in factors])
x = np.append(x, pred_100)
y = np.append(y, RMSE_baseline)

z, residuals, rank, singular_values, rcond = np.polyfit(x, y**2*n_pub-x**2, 1, full=True)
p = np.poly1d(z)

x0 = -0.5 * z[0]
c = z[1] - x0**2
print('uid = ',st)
print('x0 = ',x0)
print('{},{}'.format(st,x0))
print('c  = ',c)
print('res = ',residuals)

plt.plot(x,y**2*n_pub-x**2,'o')
xx = np.linspace(x.min(), x.max(), num=1000)
plt.plot(xx,p(xx),'--',color='r')
plt.show()

plt.plot(x,y,'o')
plt.plot(xx,((p(xx) + xx**2)/n_pub)**0.5,'--',color='r')
plt.show()
# Out:
# uid =  -2679
# x0 =  3672426.99931
# -2679,3672426.999313178
# c  =  3.55516884738e+14
# res =  [  8.40706385e+24]

# %% [markdown]
# residual is 8.4e+24 instead of 3703279.27758789 = 3.7e+6

# %% [markdown]
# Idea for fully automated method:
# - Look for the uids which coincide with no change: these are redundant
# - Look for uids which occur with None or with redundant datapoints only.
# - Try to fit with all datapoints.
#     - If redundancy is low, mark all other partners as private
#     - If residual is too high, reduce to only-me datapoints and fit again
# - Look for uids which occur only with a target-known uid
# - Fit by considering the effect of partners
# - Repeat until no uids remain, or a loop yields no new labels
