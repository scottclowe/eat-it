# %%
import datetime

# %%
import sklearn
import pandas as pd
import numpy as np

# %%
from IPython.display import HTML

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/backends/backend_gtk3agg.py:18: UserWarning: The Gtk3Agg backend is known to not work on Python 3.x with pycairo. Try installing cairocffi.
#   "The Gtk3Agg backend is known to not work on Python 3.x with pycairo. "

# %%
import holoviews as hv
# %load_ext holoviews.ipython

# %%
# %output holomap='widgets'

# %%
train = pd.read_csv('../data/train.csv', encoding="utf-8")

# %%
test = pd.read_csv('../data/test.csv', encoding="utf-8")

# %%
print(train)
# Out:
#       Id   Open Date            City  City Group Type  P1   P2   P3   P4  P5  \
# 0      0  07/17/1999        İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2
# 1      1  02/14/2008          Ankara  Big Cities   FC   4  5.0  4.0  4.0   1
# 2      2  03/09/2013      Diyarbakır       Other   IL   2  4.0  2.0  5.0   2
# 3      3  02/02/2012           Tokat       Other   IL   6  4.5  6.0  6.0   4
# 4      4  05/09/2009       Gaziantep       Other   IL   3  4.0  3.0  4.0   2
# 5      5  02/12/2010          Ankara  Big Cities   FC   6  6.0  4.5  7.5   8
# 6      6  10/11/2010        İstanbul  Big Cities   IL   2  3.0  4.0  4.0   1
# 7      7  06/21/2011        İstanbul  Big Cities   IL   4  5.0  4.0  5.0   2
# 8      8  08/28/2010  Afyonkarahisar       Other   IL   1  1.0  4.0  4.0   1
# 9      9  11/16/2011          Edirne       Other   IL   6  4.5  6.0  7.5   6
# 10    10  08/09/2013         Kocaeli       Other   FC   9  6.0  6.0  6.0   4
# 11    11  05/22/2012        İstanbul  Big Cities   IL   2  4.0  4.0  4.0   2
# 12    12  02/28/2013          Ankara  Big Cities   IL   2  2.0  4.0  4.0   2
# 13    13  10/16/2010        İstanbul  Big Cities   FC   4  5.0  4.0  4.0   1
# 14    14  12/29/2011           Bursa       Other   FC   2  2.0  4.0  4.0   1
# 15    15  02/07/2012        İstanbul  Big Cities   IL  12  7.5  6.0  6.0   2
# 16    16  01/07/2000        İstanbul  Big Cities   FC   3  5.0  4.0  4.0   2
# 17    17  11/08/2009        İstanbul  Big Cities   FC   2  4.0  4.0  5.0   1
# 18    18  04/21/2012           İzmir  Big Cities   IL   4  5.0  4.0  3.0   1
# 19    19  08/16/2011         Sakarya       Other   IL   2  4.0  4.0  4.0   2
# 20    20  08/25/2010          Elazığ       Other   IL   3  4.0  4.0  4.0   2
# 21    21  01/25/2014        İstanbul  Big Cities   FC   5  5.0  4.0  4.0   2
# 22    22  07/01/2006         Kayseri       Other   FC   9  6.0  6.0  6.0   4
# 23    23  06/03/2009         Sakarya       Other   FC   2  4.0  4.0  4.0   2
# 24    24  09/20/2009        İstanbul  Big Cities   IL   5  5.0  3.0  5.0   2
# 25    25  12/23/2011       Eskişehir       Other   FC   4  4.0  5.0  5.0   2
# 26    26  02/23/2010          Ankara  Big Cities   IL   3  5.0  4.0  5.0   2
# 27    27  10/09/1999           Bursa       Other   FC   4  5.0  4.0  3.0   1
# 28    28  01/28/1998        İstanbul  Big Cities   IL   4  5.0  4.0  4.0   1
td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>2</td>
#       <td>5</td>
#       <td>5.0</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>4</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>3.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>5</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>3</td>
#       <td>3</td>
#       <td>4316715</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>02/12/2010</td>
#       <td>Ankara</td>
#       <td>Big Cities</td>
#       <td>FC</td>
#       <td>6</td>
#       <td>6.0</td>
#       <td>4.5</td>
#       <td>7.5</td>
#       <td>8</td>
#       <td>10</td>
#       <td>10</td>
#       <td>8</td>
#       <td>8</td>
#       <td>8</td>
#       <td>10</td>
#       <td>8</td>
#       <td>6.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#       <td>6</td>
#       <td>3</td>
#       <td>1</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>7.5</td>
#       <td>5.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5017319</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>10/11/2010</td>
#       <td>İstanbul</td>
#       <td>Big Cities</td>
#       <td>IL</td>
#       <td>2</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>4.0</td>
#       <td>1</td>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>2</td>
#       <td>5</td>
#       <td>5.0</td>
#       <td>3</td>
#       <td>4</td>
#       <td>4</td>
#       <td>3</td>
#       <td>4</td>
#       <td>2</td>
#       <td>4</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>5</td>
#       <td>4</td>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>4</td>
#       <td>5</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3</td>
#       <td>5</td>
#       <td>4</td>
#       <td>4</td>
#       <td>5166635</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>06/21/2011</td>
#       <td>İstanbul</td>
#       <td>Big Cities</td>
#       <td>IL</td>
#       <td>4</td>
#       <td>5.0</td>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>2</td>
#       <td>3</td>
#       <td>5</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>3</td>
#       <td>4.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>5</td>
#       <td>2</td>
#       <td>4</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4491607</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>08/28/2010</td>
#       <td>Afyonkarahisar</td>
#       <td>Other</td>
#       <td>IL</td>
#       <td>1</td>
#       <td>1.0</td>
#       <td>4.0</td>
#       <td>4.0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>1</td>
#       <td>5</td>
#       <td>5.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>

# %%
# Calculate the age of each sample, in days
end_dt = datetime.datetime.strptime('2015-1-1', "%Y-%m-%d")
train['Age'] = [(end_dt - datetime.datetime.strptime(open_dt, "%m/%d/%Y")).days for open_dt in train['Open Date']]
test['Age']  = [(end_dt - datetime.datetime.strptime(open_dt, "%m/%d/%Y")).days for open_dt in test['Open Date']]

# %%
train['isIL'] = train['Type']=='IL'
test['isIL'] = test['Type']=='IL'

# %%
train['isBig'] = train['City Group']=='Big Cities'
test['isBig'] = test['City Group']=='Big Cities'

# %%
# Need to use binary encoder or label encoder for the city names

# %%
train.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'revenue', 'Age', 'isIL', 'isBig'], dtype='object')

# %%
test.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'Age', 'isIL', 'isBig'], dtype='object')

# %%
sum(test['Type']=='MB')
# Out:
# 290

# %%
sum(test['Type']=='DT')
# Out:
# 2244

# %%
2244/290
# Out:
# 7.7379310344827585

# %%
sum(test['Type']=='IL')/len(test), sum(test['Type']=='FC')/len(test), sum(test['Type']=='DT')/len(test), sum(test['Type']=='MB')/len(test)
# Out:
# (0.40447, 0.57018999999999997, 0.022440000000000002, 0.0028999999999999998)

# %%
p = 0.003
p*0.5 + 0.5*(1-p)*p
# Out:
# 0.0029955

# %%
li = test['Type']=='DT'

# %%
test_DT = test[li]

# %%
# %matplotlib inline

# %%
len(np.unique(test_DT['Age'].values))
# Out:
# 296

# %%
(x,b) = np.histogram(test_DT['Age'].values, 296)
plt.bar(x,b[:-1])
# Out:
# <Container object of 296 artists>

# %%
plt.bar(x,b[:-1])
# Out:
# <Container object of 296 artists>

# %%
def uniquehist(x, bins=None):
    if bins is not None:
        ux = bins
    else:
        ux = np.unique(x)
    count = np.zeros(len(ux),dtype=int)
    for ix,xx in enumerate(ux):
        count[ix] = np.sum(x==xx)
    return ux, count

# %%
ux, count = uniquehist(test_DT['Age'].values)

# %%
plt.bar(ux,count)
# Out:
# <Container object of 296 artists>

# %%
ux, count
# Out:
# (array([ 362,  380,  391,  394,  414,  419,  428,  433,  444,  448,  454,
#          468,  479,  489,  496,  511,  512,  519,  535,  538,  540,  541,
#          566,  573,  574,  582,  599,  605,  609,  610,  615,  622,  629,
#          643,  645,  666,  673,  679,  709,  713,  716,  728,  733,  739,
#          741,  751,  754,  758,  759,  770,  776,  778,  789,  795,  805,
#          808,  819,  832,  881,  899,  903,  917,  921,  929,  940,  944,
#          961,  972,  975,  978,  994, 1002, 1018, 1023, 1032, 1034, 1037,
#         1050, 1065, 1066, 1071, 1077, 1080, 1097, 1098, 1100, 1105, 1131,
#         1133, 1153, 1154, 1168, 1174, 1179, 1204, 1230, 1237, 1245, 1248,
#         1258, 1263, 1266, 1277, 1287, 1291, 1324, 1363, 1372, 1385, 1388,
#         1396, 1405, 1430, 1440, 1448, 1469, 1475, 1497, 1511, 1548, 1549,
#         1556, 1575, 1576, 1577, 1581, 1583, 1604, 1613, 1614, 1624, 1639,
#         1650, 1659, 1661, 1675, 1700, 1715, 1723, 1729, 1734, 1761, 1770,
#         1777, 1780, 1781, 1787, 1842, 1862, 1863, 1867, 1869, 1871, 1875,
#         1883, 1893, 1923, 1930, 1932, 1935, 1945, 1952, 1966, 1967, 1974,
#         1994, 2007, 2018, 2028, 2040, 2069, 2071, 2085, 2088, 2105, 2109,
#         2114, 2127, 2154, 2169, 2176, 2216, 2221, 2224, 2226, 2228, 2248,
#         2256, 2267, 2286, 2291, 2344, 2372, 2421, 2435, 2445, 2449, 2463,
#         2474, 2497, 2587, 2590, 2597, 2618, 2621, 2644, 2665, 2686, 2700,
#         2722, 2728, 2745, 2754, 2763, 2766, 2779, 2798, 2812, 2820, 2846,
#         2847, 2848, 2876, 2885, 2886, 2937, 2983, 2991, 2993, 3009, 3019,
#         3030, 3032, 3051, 3057, 3138, 3180, 3213, 3296, 3401, 3426, 3568,
#         3626, 3677, 3722, 3784, 3786, 3827, 3969, 4030, 4115, 4227, 4660,
#         4870, 4933, 5173, 5202, 5241, 5270, 5284, 5320, 5380, 5388, 5440,
#         5475, 5479, 5507, 5520, 5549, 5589, 5606, 5689, 5829, 5858, 5957,
#         6072, 6089, 6114, 6142, 6149, 6153, 6168, 6210, 6221, 6326, 6389,
#         6395, 6454, 6473, 6691, 6704, 6876, 6985, 7016, 7092, 7178]),
#  array([  4,   2,   1,   1,   2,   4,   3,   3,   6,   4,   5,   9,   2,
#           4,   3,   1,   6,   5,   4,   5,   6,   4,   2,   2,   2,   4,
#           3,   5,   3,   5,   3,   3,   1,   5,   2,   2,   5,   4,   2,
#           6,   3,   3,   3,   1,   3,   2,   4,   5,   4,   4,   3,   4,
#           1,   3,   4,   1,   3,   2,   4,   8,   4,   4,   1,   3,   1,
#           7,   3,   2,   3,   1,   3,   3,   4,   6,   4,   5,   2,   2,
#           5,   6,   1,   4,   5,   3,   1,   6,   3,   5,   1,   2,   2,
#           5,   3,   9,   3,   1,   5,   2,   2,   3,   5,   4,   6,   1,
#           1,   2,   5,   1,   2,   4,   2,   1,   3,   4,   1,   2,   2,
#           3,   2,   4,   3,   5,   3,   6,   3,   5,   2,   3,   7,   4,
#           6,   3,   4,   3,   1,   4,   2,   3,   3,   2,   3,   1,   4,
#           5,   2,   4,   2,   3,   7,   3,   6,   5,   6,   1,   4,   3,
#           2,   3,   8,   4,   4,   3,   5,   5,   2,   5,   1,   2,   5,
#           4,   3,   4,   4,   2,   3,   7,   1,   2,   3,   3,   4,   4,
#           3,   7,   1,   2,   3,   1,   8,   8,   2,   6,   2,   2,   1,
#           4,   2,   6,   2,   3,   3,   3,   1,   3,   3,   3,   2,   3,
#           2,   1,   2,   3,   8,   1,   4,   4,   1,   5,   4,   9,   8,
#           3,   5,   4,   2,   3,   3,   5,   4,   1,   5,   3,   2,   4,
#           5,   3,   2,   1,   3,   4,   4,   6,   2, 181,   1,   2,   4,
#           2,   2,   3,   3,   2,   3,   4,   2,   4,   6, 174, 181,   4,
#           1,   2,   2, 183,   3,   5,   4,   7, 191, 173,   5,   1,   4,
#           7, 191,   2,   1,   2,   1,   6,   1,   6,   4,   1,   4,   2,
#           2,   3,   2,   4,   2,   3,   3,   1,   2,   3]))

# %%
plt.plot(ux,count)

# %%
sum(count>50)
# Out:
# 7

# %%
sum(test['Type']=='DT') + sum(test['Type']=='MB')
# Out:
# 2534

# %%
len(test)
# Out:
# 100000

# %%
len(test) / (sum(test['Type']=='DT') + sum(test['Type']=='MB')) * 8
# Out:
# 315.70639305445934

# %% [markdown]
# # Clustering?

# %%
import sklearn.cluster

# %%
clst= sklearn.cluster.KMeans(316)

# %%
test.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'Age', 'isIL', 'isBig'], dtype='object')

# %%
cols = ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10',
        'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20',
        'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29', 'P30',
        'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'Age', 'isIL', 'isBig']

# %%
X = test[cols].as_matrix()

# %%
X.shape
# Out:
# (100000, 40)

# %%
X2 = X - X.min(0)
X2 = X2 / X.max(0)

# %%
C = clst.fit_predict(X2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-8d978d11c509> in <module>()
# ----> 1 C = clst.fit_predict(X2)
#
# /usr/local/lib/python3.4/dist-packages/sklearn/cluster/k_means_.py in fit_predict(self, X)
#     738         predict(X).
#     739         """
# --> 740         return self.fit(X).labels_
#     741
#     742     def fit_transform(self, X, y=None):
#
# /usr/local/lib/python3.4/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#     729             precompute_distances=self.precompute_distances,
#     730             tol=self.tol, random_state=random_state, copy_x=self.copy_x,
# --> 731             n_jobs=self.n_jobs)
#     732         return self
#     733
#
# /usr/local/lib/python3.4/dist-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs)
#     263                 X, n_clusters, max_iter=max_iter, init=init, verbose=verbose,
#     264                 precompute_distances=precompute_distances, tol=tol,
# --> 265                 x_squared_norms=x_squared_norms, random_state=random_state)
#     266             # determine if these results are the best so far
#     267             if best_inertia is None or inertia < best_inertia:
#
# /usr/local/lib/python3.4/dist-packages/sklearn/cluster/k_means_.py in _kmeans_single(X, n_clusters, x_squared_norms, max_iter, init, verbose, random_state, tol, precompute_distances)
#     374             _labels_inertia(X, x_squared_norms, centers,
#     375                             precompute_distances=precompute_distances,
# --> 376                             distances=distances)
#     377
#     378         # computation of the means is also called the M-step of EM
#
# /usr/local/lib/python3.4/dist-packages/sklearn/cluster/k_means_.py in _labels_inertia(X, x_squared_norms, centers, precompute_distances, distances)
#     492         if precompute_distances:
#     493             return _labels_inertia_precompute_dense(X, x_squared_norms,
# --> 494                                                     centers, distances)
#     495         inertia = _k_means._assign_labels_array(
#     496             X, x_squared_norms, centers, labels, distances=distances)
#
# /usr/local/lib/python3.4/dist-packages/sklearn/cluster/k_means_.py in _labels_inertia_precompute_dense(X, x_squared_norms, centers, distances)
#     429     k = centers.shape[0]
#     430     all_distances = euclidean_distances(centers, X, x_squared_norms,
# --> 431                                         squared=True)
#     432     labels = np.empty(n_samples, dtype=np.int32)
#     433     labels.fill(-1)
#
# /usr/local/lib/python3.4/dist-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared)
#     212         XX = row_norms(X, squared=True)[:, np.newaxis]
#     213
# --> 214     distances = safe_sparse_dot(X, Y.T, dense_output=True)
#     215     distances *= -2
#     216     distances += XX
#
# /usr/local/lib/python3.4/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     178         return ret
#     179     else:
# --> 180         return fast_dot(a, b)
#     181
#     182
#
# KeyboardInterrupt:

# %%
clst.n_clusters

# %%
clst.labels_
# Out:
# array([211,  13,  61, ..., 275, 201, 269], dtype=int32)

# %%
C
# Out:
# array([211,  13,  61, ..., 275, 201, 269], dtype=int32)

# %%
liC0 = C==0

# %%
test[liC0]
# Out:
# 14387  ...      0    0    0    0    0    0    0   929  False  False
# 14474  ...      0    0    0    0    0    0    0   929  False  False
# 14825  ...      1    0    0    0    0    0    0   929  False  False
# 16914  ...      0    0    0    0    0    0    0   929  False  False
# 18176  ...      0    0    0    0    0    0    0   929  False  False
# 18486  ...      0    0    0    0    0    0    0   929  False  False
# 19012  ...      0    5    3    0    0    0    4   929  False  False
# 19248  ...      0    0    0    0    0    5    0   929  False  False
# 20023  ...      0    0    0    0    0    0    0   929  False  False
# 20120  ...      0    0    0    3    0    3    0  2763  False  False
# 20672  ...      0    0    0    3    0    0    0   929  False  False
# ...    ...    ...  ...  ...  ...  ...  ...  ...   ...    ...    ...
# 80302  ...      0    0    0    0    0    0    0   929  False  False
# 82010  ...      0    0    0    0    0    0    0   929  False  False
# 82281  ...      0    0    0    0    0    0    0   643  False  False
# 83596  ...      0    0    0    0    0    0    0  2085  False  False
# 84123  ...      0    0    0    0    0    0    0   929  False  False
# 84575  ...      0    0    0    0    0    0    0   929  False  False
# 85504  ...      0    4    0    0    0    0    0  6454  False  False
# 85631  ...      0    0    0    0    0    0    0   808  False  False
# 85862  ...      0    0    0    0    0    3    0   929  False  False
# 87491  ...      0    0    2    0    4    0    0   929  False  False
# 88266  ...      0    0    0    0    0    0    0   929  False  False
# 88466  ...      0    0    3    0    0    0    0  5589  False  False
# 89819  ...      0    0    0    0    0    0    0   929  False  False
# 90820  ...      0    0    0    0    0    0    0  1372  False  False
# 91315  ...      0    0    0    0    0    0    0  3677  False  False
# 91576  ...      0    0    0    0    0    0    0   929  False  False
# 91585  ...      0    0    0    0    0    0    0   929  False  False
# 92516  ...      0    0    0    0    0    0    0   929  False  False
# 93406  ...      0    0    0    0    0    0    0   929  False  False
# 93626  ...      0    0    0    0    0    0    0  4227  False  False
# 93824  ...      2    0    3    0    1    0    0  2256  False  False
# 94838  ...      0    0    0    0    0    0    0   929  False  False
# 95808  ...      5    0    0    0    4    0    0   929  False  False
# 96380  ...      0    0    0    0    0    0    0   929  False  False
# 97435  ...      0    0    0    0    0    0    0   929  False  False
# 97864  ...      0    0    0    0    0    0    0  1174  False  False
# 98449  ...      0    0    0    0    0    0    0   929  False  False
# 99043  ...      0    0    0    0    0    0    0  1237  False  False
# 99487  ...      0    0    0    0    0    0    0  2474  False  False
# 99711  ...      0    0    0    0    0    0    0  2372  False  False
#
# [146 rows x 45 columns]

# %%
clst2 = sklearn.cluster.DBSCAN()

# %%
C2 = clst2.fit_predict(X)

# %%
clst2.components_.shape

# %%
len(np.unique(C2))

# %%
import sklearn.metrics.pairwise

# %%
help(sklearn.metrics.pairwise)

# %%
import time

# %%
X_dist = np.zeros((X.shape[0],X.shape[0]),dtype=np.uint8)
start_time = time.time()
for i in range(X.shape[0]):
    X_dist[:,i] = np.sum(X == np.expand_dims(X[i,:],0), 1)
    if i%1000==0:
        print(i, time.time()-start_time)

# %% [markdown]
# This will work, but I don't have time now. Not sure if I have enough diskspace to save it to my laptop, either.

# %% [markdown]
# # Age-driven selection

# %% [markdown]
#   array([ 0.19478,  0.07887,  0.11931,  0.1209 ,  0.36731,  0.01825,
#           0.00322,  0.01954,  0.07782])),
#  'P21': (array([ 1,  2,  3,  4,  5,  6,  9, 12, 15]),
#   array([ 0.44237,  0.21538,  0.17461,  0.04395,  0.04999,  0.02881,
#           0.01641,  0.00936,  0.01912])),
#  'P22': (array([1, 2, 3, 4, 5]),
#   array([ 0.34173,  0.23561,  0.18858,  0.11871,  0.11537])),
#  'P23': (array([ 1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.3989 ,  0.16741,  0.11561,  0.08512,  0.1434 ,  0.03038,
#           0.02198,  0.01231,  0.02489])),
#  'P24': (array([ 0,  1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.65766,  0.04047,  0.07435,  0.08173,  0.03721,  0.07463,
#           0.01235,  0.006  ,  0.0156 ])),
#  'P25': (array([ 0,  1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.65738,  0.04429,  0.0622 ,  0.05538,  0.09426,  0.05596,
#           0.01171,  0.00301,  0.01581])),
#  'P26': (array([  0. ,   1. ,   2. ,   2.5,   3. ,   4. ,   5. ,   7.5,  10. ,  12.5]),
#   array([ 0.65784,  0.05326,  0.05965,  0.00948,  0.07518,  0.04086,
#           0.06425,  0.01782,  0.01249,  0.00917])),
#  'P27': (array([  0. ,   1. ,   2. ,   2.5,   3. ,   4. ,   5. ,   7.5,  10. ,  12.5]),
#   array([ 0.66193,  0.06428,  0.04738,  0.03328,  0.06331,  0.05303,
#           0.05553,  0.00312,  0.00306,  0.01508])),
#  'P28': (array([  1. ,   2. ,   2.5,   3. ,   4. ,   5. ,   7.5,  10. ,  12.5]),
#   array([ 0.15207,  0.29496,  0.02474,  0.20559,  0.093  ,  0.16329,
#           0.02825,  0.02536,  0.01274])),
#  'P29': (array([  0. ,   1. ,   2. ,   2.5,   3. ,   5. ,   7.5,  10. ]),
#   array([ 0.03083,  0.09495,  0.17339,  0.01286,  0.55099,  0.03112,
#           0.10282,  0.00304])),
#  'P3': (array([ 0. ,  2. ,  3. ,  4. ,  4.5,  5. ,  6. ]),
#   array([ 0.00318,  0.01906,  0.07178,  0.66698,  0.02781,  0.09834,  0.11285])),
#  'P30': (array([ 0,  1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.65596,  0.02182,  0.01586,  0.06908,  0.04388,  0.14093,
#           0.00586,  0.01859,  0.01912,  0.0089 ])),
#  'P31': (array([ 0,  1,  2,  3,  4,  5,  6,  9, 12, 15]),
#   array([ 0.65566,  0.10074,  0.03672,  0.08129,  0.01613,  0.07827,
#           0.00585,  0.01282,  0.00629,  0.00623])),
#  'P32': (array([ 0,  1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.65787,  0.00963,  0.03793,  0.07465,  0.0787 ,  0.08314,
#           0.01801,  0.02182,  0.01219,  0.00606])),
#  'P33': (array([0, 1, 2, 3, 4, 5, 6]),
#   array([ 0.65791,  0.01523,  0.14955,  0.08397,  0.06429,  0.01027,  0.01878])),
#  'P34': (array([ 0,  1,  2,  3,  4,  5,  6, 12, 18, 24, 30]),
#   array([ 0.65832,  0.00649,  0.02253,  0.10863,  0.10628,  0.03921,
#           0.00301,  0.0061 ,  0.031  ,  0.01535,  0.00308])),
#  'P35': (array([ 0,  1,  2,  4,  5, 12, 15]),
#   array([ 0.65776,  0.02486,  0.0091 ,  0.18842,  0.06155,  0.04877,  0.00954])),
#  'P36': (array([ 0,  1,  2,  3,  4,  5,  8, 12, 16, 20]),
#   array([ 0.65662,  0.00313,  0.01271,  0.09157,  0.10913,  0.06851,
#           0.00293,  0.01536,  0.0305 ,  0.00954])),
#  'P37': (array([0, 1, 2, 3, 4, 5, 6, 8]),
#   array([ 0.66029,  0.08368,  0.06943,  0.0941 ,  0.05062,  0.0088 ,
#           0.02123,  0.01185])),
#  'P4': (array([ 2. ,  3. ,  4. ,  4.5,  5. ,  6. ,  7.5]),
#   array([ 0.00311,  0.1177 ,  0.56508,  0.00606,  0.16457,  0.09989,  0.04359])),
#  'P5': (array([1, 2, 3, 4, 5, 6]),
#   array([ 0.33587,  0.50633,  0.03721,  0.09562,  0.00287,  0.0221 ])),
#  'P6': (array([ 1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.0985 ,  0.43925,  0.1808 ,  0.15952,  0.0755 ,  0.02474,
#           0.00921,  0.01248])),
#  'P7': (array([ 1,  2,  3,  4,  5,  6, 10]),
#   array([ 0.06886,  0.02223,  0.01572,  0.01884,  0.73343,  0.00292,  0.138  ])),
#  'P8': (array([ 1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.00639,  0.01567,  0.06177,  0.38154,  0.39394,  0.0159 ,
#           0.0656 ,  0.05919])),
#  'P9': (array([ 4,  5,  6,  8, 10]),
#   array([ 0.35153,  0.49932,  0.00307,  0.06528,  0.0808 ])),
#  'isBig': (array([False,  True], dtype=bool), array([ 0.50728,  0.49272])),
#  'isIL': (array([False,  True], dtype=bool), array([ 0.59553,  0.40447]))}

# %%
for col in cols:
    plt.bar(uhistdict[col][0],uhistdict[col][1])
    plt.title(col)
    plt.show()
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
# /usr/local/lib/python3.4/dist-packages/matplotlib/transforms.py:1883: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)

# %%
expected_age_count = np.median(uhistdict['Age'][1])
li = uhistdict['Age'][1] > expected_age_count*1.5
print(uhistdict['Age'][0][li])
print(uhistdict['Age'][1][li])
# Out:
# [ 468  538  540  605  805  944 1100 1277 1675 2085 6876]
# [ 0.00632  0.00594  0.00645  0.00635  0.00607  0.00615  0.00601  0.00635
#   0.00597  0.00625  0.00631]

# %%
n_true = len(uhistdict['Age'][0]) + sum(li)
print('Number of true examples is ', n_true)
print('Number of public examples is ', n_true*0.3)
# Out:
# Number of true examples is  321
# Number of public examples is  96.3

# %%
import pickle

# %%
genuinetestmap = pickle.load(open('../data/genuinetestmap.pkl', 'rb'))

]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-06ad2d684861> in <module>()
# ----> 1 group0 = test[C==0]
#
# NameError: name 'C' is not defined

# %%
group_centre = group0[cols][0:1]
group_centre['Id'] = -1
for col in cols:
    x,y = uniquehist(group0[col].values, uhistdict[col][0])
    y = y/sum(y)
    print(np.vstack((y, uhistdict[col][1])))
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]

# %%
HTML(group_centre.to_html())

# %%
group0.as_matrix().shape

# %%
li_centre = np.ones(len(group0))
for col in cols:
    li_centre = li_centre * (group0[col].values == group_centre[col].values)

# %%
sum(li_centre)

# %%
for iGroup in np.unique(C):
    group = test[C==iGroup]
    group_centre = group[cols][0:1]
    group_centre['Id'] = -1
    for col in cols:
        x,y = uniquehist(group[col].values, uhistdict[col][0])
        y = y/sum(y)
        idx = np.argmax(y - uhistdict[col][1])
        group_centre[col] = uhistdict[col][0][idx]
    li_centre = np.ones(len(group),dtype=bool)
    for col in cols:
        li_centre = li_centre * (group[col].values == group_centre[col].values)
    print(iGroup, sum(li_centre))

# %%
uhistdict
# Out:
# {'Age': (array([ 362,  380,  391,  394,  414,  419,  428,  433,  444,  446,  448,
#           454,  468,  479,  489,  496,  511,  512,  519,  535,  538,  540,
#           541,  566,  573,  574,  582,  599,  605,  608,  609,  610,  615,
#           622,  629,  643,  645,  666,  673,  679,  709,  713,  716,  728,
#           733,  739,  741,  751,  754,  758,  759,  770,  776,  778,  789,
#           795,  805,  808,  819,  832,  866,  881,  899,  903,  917,  921,
#           929,  940,  944,  961,  972,  975,  978,  994, 1002, 1018, 1023,
#          1032, 1034, 1037, 1050, 1065, 1066, 1071, 1077, 1080, 1097, 1098,
#          1100, 1105, 1116, 1131, 1133, 1153, 1154, 1168, 1174, 1179, 1204,
#          1230, 1237, 1245, 1248, 1258, 1263, 1266, 1277, 1287, 1291, 1324,
#          1363, 1372, 1385, 1388, 1396, 1405, 1430, 1440, 1448, 1455, 1465,
#          1469, 1475, 1476, 1497, 1511, 1543, 1548, 1549, 1556, 1575, 1576,
#          1577, 1581, 1583, 1604, 1613, 1614, 1616, 1624, 1639, 1650, 1659,
#          1661, 1675, 1700, 1706, 1715, 1723, 1729, 1734, 1761, 1770, 1777,
#          1780, 1781, 1787, 1842, 1862, 1863, 1866, 1867, 1869, 1871, 1875,
#          1883, 1893, 1923, 1930, 1932, 1935, 1945, 1952, 1966, 1967, 1974,
#          1994, 2007, 2018, 2028, 2040, 2069, 2071, 2085, 2088, 2105, 2109,
#          2114, 2127, 2154, 2169, 2176, 2216, 2221, 2224, 2226, 2228, 2248,
#          2256, 2267, 2286, 2291, 2344, 2372, 2421, 2435, 2445, 2449, 2463,
#          2474, 2497, 2587, 2590, 2597, 2618, 2621, 2644, 2665, 2686, 2700,
#          2722, 2728, 2745, 2754, 2763, 2766, 2779, 2798, 2812, 2820, 2846,
#          2847, 2848, 2876, 2885, 2886, 2937, 2983, 2991, 2993, 3009, 3019,
#          3030, 3032, 3051, 3057, 3124, 3138, 3180, 3213, 3296, 3401, 3426,
#          3568, 3626, 3677, 3722, 3784, 3786, 3827, 3969, 4030, 4115, 4227,
#          4660, 4870, 4933, 5173, 5202, 5241, 5266, 5270, 5284, 5320, 5380,
#           0.00607,  0.0423 ,  0.00598])),
#  'P19': (array([ 1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.13528,  0.15601,  0.21177,  0.12839,  0.24328,  0.02872,
#           0.01821,  0.02806,  0.05028])),
#  'P2': (array([ 1. ,  1.5,  2. ,  3. ,  4. ,  4.5,  5. ,  6. ,  7.5]),
#   array([ 0.01185,  0.00318,  0.08719,  0.14778,  0.1932 ,  0.02274,
#           0.4126 ,  0.03689,  0.08457])),
#  'P20': (array([ 1,  2,  3,  4,  5,  6,  9, 12, 15]),
#   array([ 0.19478,  0.07887,  0.11931,  0.1209 ,  0.36731,  0.01825,
#           0.00322,  0.01954,  0.07782])),
#  'P21': (array([ 1,  2,  3,  4,  5,  6,  9, 12, 15]),
#   array([ 0.44237,  0.21538,  0.17461,  0.04395,  0.04999,  0.02881,
#           0.01641,  0.00936,  0.01912])),
#  'P22': (array([1, 2, 3, 4, 5]),
#   array([ 0.34173,  0.23561,  0.18858,  0.11871,  0.11537])),
#  'P23': (array([ 1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.3989 ,  0.16741,  0.11561,  0.08512,  0.1434 ,  0.03038,
#           0.02198,  0.01231,  0.02489])),
#  'P24': (array([ 0,  1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.65766,  0.04047,  0.07435,  0.08173,  0.03721,  0.07463,
#           0.01235,  0.006  ,  0.0156 ])),
#  'P25': (array([ 0,  1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.65738,  0.04429,  0.0622 ,  0.05538,  0.09426,  0.05596,
#           0.01171,  0.00301,  0.01581])),
#  'P26': (array([  0. ,   1. ,   2. ,   2.5,   3. ,   4. ,   5. ,   7.5,  10. ,  12.5]),
#   array([ 0.65784,  0.05326,  0.05965,  0.00948,  0.07518,  0.04086,
#           0.06425,  0.01782,  0.01249,  0.00917])),
#  'P27': (array([  0. ,   1. ,   2. ,   2.5,   3. ,   4. ,   5. ,   7.5,  10. ,  12.5]),
#   array([ 0.66193,  0.06428,  0.04738,  0.03328,  0.06331,  0.05303,
#           0.05553,  0.00312,  0.00306,  0.01508])),
#  'P28': (array([  1. ,   2. ,   2.5,   3. ,   4. ,   5. ,   7.5,  10. ,  12.5]),
#   array([ 0.15207,  0.29496,  0.02474,  0.20559,  0.093  ,  0.16329,
#           0.02825,  0.02536,  0.01274])),
#  'P29': (array([  0. ,   1. ,   2. ,   2.5,   3. ,   5. ,   7.5,  10. ]),
#   array([ 0.03083,  0.09495,  0.17339,  0.01286,  0.55099,  0.03112,
#           0.10282,  0.00304])),
#  'P3': (array([ 0. ,  2. ,  3. ,  4. ,  4.5,  5. ,  6. ]),
#   array([ 0.00318,  0.01906,  0.07178,  0.66698,  0.02781,  0.09834,  0.11285])),
#  'P30': (array([ 0,  1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.65596,  0.02182,  0.01586,  0.06908,  0.04388,  0.14093,
#           0.00586,  0.01859,  0.01912,  0.0089 ])),
#  'P31': (array([ 0,  1,  2,  3,  4,  5,  6,  9, 12, 15]),
#   array([ 0.65566,  0.10074,  0.03672,  0.08129,  0.01613,  0.07827,
#           0.00585,  0.01282,  0.00629,  0.00623])),
#  'P32': (array([ 0,  1,  2,  3,  4,  5, 10, 15, 20, 25]),
#   array([ 0.65787,  0.00963,  0.03793,  0.07465,  0.0787 ,  0.08314,
#           0.01801,  0.02182,  0.01219,  0.00606])),
#  'P33': (array([0, 1, 2, 3, 4, 5, 6]),
#   array([ 0.65791,  0.01523,  0.14955,  0.08397,  0.06429,  0.01027,  0.01878])),
#  'P34': (array([ 0,  1,  2,  3,  4,  5,  6, 12, 18, 24, 30]),
#   array([ 0.65832,  0.00649,  0.02253,  0.10863,  0.10628,  0.03921,
#           0.00301,  0.0061 ,  0.031  ,  0.01535,  0.00308])),
#  'P35': (array([ 0,  1,  2,  4,  5, 12, 15]),
#   array([ 0.65776,  0.02486,  0.0091 ,  0.18842,  0.06155,  0.04877,  0.00954])),
#  'P36': (array([ 0,  1,  2,  3,  4,  5,  8, 12, 16, 20]),
#   array([ 0.65662,  0.00313,  0.01271,  0.09157,  0.10913,  0.06851,
#           0.00293,  0.01536,  0.0305 ,  0.00954])),
#  'P37': (array([0, 1, 2, 3, 4, 5, 6, 8]),
#   array([ 0.66029,  0.08368,  0.06943,  0.0941 ,  0.05062,  0.0088 ,
#           0.02123,  0.01185])),
#  'P4': (array([ 2. ,  3. ,  4. ,  4.5,  5. ,  6. ,  7.5]),
#   array([ 0.00311,  0.1177 ,  0.56508,  0.00606,  0.16457,  0.09989,  0.04359])),
#  'P5': (array([1, 2, 3, 4, 5, 6]),
#   array([ 0.33587,  0.50633,  0.03721,  0.09562,  0.00287,  0.0221 ])),
#  'P6': (array([ 1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.0985 ,  0.43925,  0.1808 ,  0.15952,  0.0755 ,  0.02474,
#           0.00921,  0.01248])),
#  'P7': (array([ 1,  2,  3,  4,  5,  6, 10]),
#   array([ 0.06886,  0.02223,  0.01572,  0.01884,  0.73343,  0.00292,  0.138  ])),
#  'P8': (array([ 1,  2,  3,  4,  5,  6,  8, 10]),
#   array([ 0.00639,  0.01567,  0.06177,  0.38154,  0.39394,  0.0159 ,
#           0.0656 ,  0.05919])),
#  'P9': (array([ 4,  5,  6,  8, 10]),
#   array([ 0.35153,  0.49932,  0.00307,  0.06528,  0.0808 ])),
#  'isBig': (array([False,  True], dtype=bool), array([ 0.50728,  0.49272])),
#  'isIL': (array([False,  True], dtype=bool), array([ 0.59553,  0.40447]))}

# %%
smallest_value = (None,None,1.0)
for col in cols:
    idx = np.argmin(uhistdict[col][1])
    print(col,uhistdict[col][0][idx],uhistdict[col][1][idx])
    if uhistdict[col][1][idx] < smallest_value[2]:
        smallest_value = (col,uhistdict[col][0][idx],uhistdict[col][1][idx])
# Out:
# P1 15 0.00897
# P2 1.5 0.00318
# P3 0.0 0.00318
# P4 2.0 0.00311
# P5 5 0.00287
# P6 8 0.00921
# P7 6 0.00292
# P8 1 0.00639
# P9 6 0.00307
# P10 8 0.04054
# P11 8 0.00958
# P12 2 0.01275
# P13 3.0 0.01247
# P14 12 0.006
# P15 6 0.00304
# P16 1 0.00315
# P17 6 0.00307
# P18 2 0.00322
# P19 15 0.01821
# P20 9 0.00322
# P21 12 0.00936
# P22 5 0.11537
# P23 20 0.01231
# P24 8 0.006
# P25 8 0.00301
# P26 12.5 0.00917
# P27 10.0 0.00306
# P28 12.5 0.01274
# P29 10.0 0.00304
# P30 10 0.00586
# P31 6 0.00585
# P32 25 0.00606
# P33 5 0.01027
# P34 6 0.00301
# P35 2 0.0091
# P36 8 0.00293
# P37 5 0.0088
# Age 739 0.00265
# isIL True 0.40447
# isBig True 0.49272

# %%
smallest_value
# Out:
# ('Age', 739, 0.00265)

# %%
smallest_value[2]*100000
# Out:
# 265.0

# %%
len(uhistdict['Age'][0])
# Out:
# 310

# %%
li_ = test['Age'].values==739

# %%
test[li_]
# Out:
#           Id   Open Date       City  City Group Type  P1   P2   P3   P4  P5  \
# 250      250  12/23/2012   İstanbul  Big Cities   IL   2  2.0  3.0  5.0   2
# 411      411  12/23/2012     Ankara  Big Cities   IL   4  5.0  4.0  4.0   2
# 593      593  12/23/2012    Trabzon       Other   IL   2  5.0  3.0  5.0   2
# 649      649  12/23/2012     Mardin       Other   FC   2  7.5  6.0  6.0   4
# 1674    1674  12/23/2012   İstanbul  Big Cities   IL   2  5.0  6.0  5.0   2
# 2244    2244  12/23/2012     Mardin       Other   IL   2  2.0  3.0  5.0   2
# 2548    2548  12/23/2012   İstanbul  Big Cities   FC   3  5.0  3.0  4.0   2
# 3084    3084  12/23/2012     Mardin       Other   IL   2  2.0  3.0  5.0   2
# 3113    3113  12/23/2012    Antalya       Other   IL   1  1.0  4.0  5.0   2
# 3744    3744  12/23/2012     Mardin       Other   IL   4  5.0  3.0  4.0   1
# 3768    3768  12/23/2012     Mardin       Other   IL   4  2.0  3.0  5.0   2
# 3841    3841  12/23/2012   İstanbul  Big Cities   IL   2  2.0  3.0  5.0   2
# 4172    4172  12/23/2012     Ankara  Big Cities   FC   5  2.0  3.0  5.0   2
# 4681    4681  12/23/2012      Konya       Other   IL   2  2.0  4.0  5.0   2
# 4840    4840  12/23/2012   İstanbul  Big Cities   IL   4  2.0  3.0  5.0   2
# 4992    4992  12/23/2012   Kırşehir       Other   IL   4  2.0  4.0  4.0   2
# 5155    5155  12/23/2012      Çorum       Other   IL   2  2.0  4.0  5.0   2
# 5195    5195  12/23/2012    Kocaeli       Other   IL   2  4.0  4.0  5.0   2
# 5213    5213  12/23/2012   İstanbul  Big Cities   IL   2  2.0  3.0  5.0   2
# 5323    5323  12/23/2012      Sivas       Other   IL   2  2.0  4.0  4.0   2
# 5546    5546  12/23/2012     Mardin       Other   IL   2  2.0  3.0  5.0   2
# 5761    5761  12/23/2012      İzmir  Big Cities   IL   4  5.0  6.0  4.0   2
# 6806    6806  12/23/2012      Aydın       Other   FC   9  6.0  3.0  5.0   2
# 96617  ...      0    0    0    0    0    0    0  739  False  False
# 96816  ...      0    0    0    0    0    0    0  739   True  False
# 97107  ...      0    0    0    0    0    0    0  739   True  False
# 97207  ...      0    0    0    0    0    0    0  739   True   True
# 98039  ...      0    0    0    0    0    0    4  739   True  False
# 98469  ...      0    4    4    0    4    0    0  739  False   True
# 98584  ...      0    0    0    0    0    0    0  739   True  False
# 98979  ...      0    0    0    0    0    4    0  739  False  False
# 99110  ...      0    0    0    0    0    0    0  739   True  False
# 99574  ...      0    0    0    0    0    0    0  739  False   True
# 99819  ...      0    0    0    0    0    0    0  739  False  False
#
# [265 rows x 45 columns]

# %%
allcols = test.columns
uhistdict = {}
for col in allcols:
    x,y = uniquehist(test[col].values)
    uhistdict[col] = (x,y/sum(y))

# %%
li_ = test['Age'].values==739
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
# Out:
# 2

# %%
HTML(group[li_centre].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>Open Date</th>
#       <th>City</th>
#       <th>City Group</th>
#       <th>Type</th>
#       <th>P1</th>
#       <th>P2</th>
#       <th>P3</th>
#       <th>P4</th>
#       <th>P5</th>
#       <th>P6</th>
#       <th>P7</th>
#       <th>P8</th>
#       <th>P9</th>
#       <th>P10</th>
#       <th>P11</th>
#       <th>P12</th>
#       <th>P13</th>
#       <th>P14</th>
#       <th>P15</th>
#       <th>P16</th>
#       <th>P17</th>
#       <th>P18</th>
#       <th>P19</th>
#       <th>P20</th>
#       <th>P21</th>
#       <th>P22</th>
#       <th>P23</th>
#       <th>P24</th>
#       <th>P25</th>
#       <th>P26</th>
#       <th>P27</th>
#       <th>P28</th>
#       <th>P29</th>
#       <th>P30</th>
#       <th>P31</th>
#       <th>P32</th>
#       <th>P33</th>
#       <th>P34</th>
#       <th>P35</th>
#       <th>P36</th>
#       <th>P37</th>
#       <th>Age</th>
#       <th>isIL</th>
#       <th>isBig</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2244</th>
#       <td>2244</td>
#       <td>12/23/2012</td>
#       <td>Mardin</td>
#       <td>Other</td>
#       <td>IL</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3</td>
#       <td>5</td>
#       <td>2</td>
#       <td>1</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>3</td>
#       <td>4</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>739</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>90048</th>
#       <td>90048</td>
#       <td>12/23/2012</td>
#       <td>Mardin</td>
#       <td>Other</td>
#       <td>IL</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3</td>
#       <td>5</td>
#       <td>2</td>
#       <td>1</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>3</td>
#       <td>4</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>739</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>

# %%
group_centre
# Out:
# {'Age': 739,
#  'City': 'Mardin',
#  'City Group': 'Other',
#  'Open Date': '12/23/2012',
#  'P1': 2,
#  'P10': 4,
#  'P11': 3,
#  'P12': 4,
#  'P13': 4.0,
#  'P14': 0,
#  'P15': 0,
#  'P16': 0,
#  'P17': 0,
#  'P18': 0,
#  'P19': 3,
#  'P2': 2.0,
#  'P20': 4,
#  'P21': 1,
#  'P22': 1,
#  'P23': 2,
#  'P24': 0,
#  'P25': 0,
#  'P26': 0.0,
#  'P27': 0.0,
#  'P28': 2.0,
#  'P29': 3.0,
#  'P3': 3.0,
#  'P30': 0,
#  'P31': 0,
#  'P32': 0,
#  'P33': 0,
#  'P34': 0,
#  'P35': 0,
#  'P36': 0,
#  'P37': 0,
#  'P4': 5.0,
#  'P5': 2,
#  'P6': 1,
#  'P7': 4,
#  'P8': 4,
#  'P9': 4,
#  'Type': 'IL',
#  'isBig': False,
#  'isIL': True}

# %%
li_ = test['Age'].values==362
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
# Out:
# 2
#         Id   Open Date   City City Group Type  P1  P2  P3  P4  P5  ...    P31  \
# 2679  2679  01/04/2014  Adana      Other   IL   4   5   4   4   1  ...      0
# 6347  6347  01/04/2014  Adana      Other   IL   4   5   4   4   1  ...      0
#
#       P32  P33  P34  P35  P36  P37  Age  isIL  isBig
# 2679    0    0    0    0    0    0  362  True  False
# 6347    0    0    0    0    0    0  362  True  False
#
# [2 rows x 45 columns]

# %%
li_ = test['Age'].values==7178
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
# Out:
# 3
#           Id   Open Date      City  City Group Type  P1  P2  P3  P4  P5  \
# 6212    6212  05/08/1995  İstanbul  Big Cities   IL   4   5   5   3   1
# 17479  17479  05/08/1995  İstanbul  Big Cities   IL   4   5   5   3   1
# 47342  47342  05/08/1995  İstanbul  Big Cities   IL   4   5   5   3   1
#
#        ...    P31  P32  P33  P34  P35  P36  P37   Age  isIL  isBig
# 6212   ...      1    2    1    1    5    3    1  7178  True   True
# 17479  ...      1    2    1    1    5    3    1  7178  True   True
# 47342  ...      1    2    1    1    5    3    1  7178  True   True
#
# [3 rows x 45 columns]

# %%
li_ = test['Age'].values==380
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
# Out:
# 1
#           Id   Open Date    City City Group Type  P1  P2  P3  P4  P5  ...    \
# 84446  84446  12/17/2013  Batman      Other   FC   3   4   2   4   2  ...
#
#        P31  P32  P33  P34  P35  P36  P37  Age   isIL  isBig
# 84446    0    0    0    0    0    0    0  380  False  False
#
# [1 rows x 45 columns]

# %%
li_ = test['Age'].values==391
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
# Out:
# 3
#           Id   Open Date    City City Group Type  P1  P2  P3  P4  P5  ...    \
# 29949  29949  12/06/2013  Mersin      Other   IL   2   3   4   4   1  ...
# 64895  64895  12/06/2013  Mersin      Other   IL   2   3   4   4   1  ...
# 83582  83582  12/06/2013  Mersin      Other   IL   2   3   4   4   1  ...
#
#        P31  P32  P33  P34  P35  P36  P37  Age  isIL  isBig
# 29949    0    0    0    0    0    0    0  391  True  False
# 64895    0    0    0    0    0    0    0  391  True  False
# 83582    0    0    0    0    0    0    0  391  True  False
#
# [3 rows x 45 columns]

# %%
li_ = test['Age'].values==7092
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
# Out:
# 6
#           Id   Open Date      City  City Group Type  P1  P2  P3  P4  P5  \
# 11153  11153  08/02/1995  İstanbul  Big Cities   IL   3   5   4   5   2
# 62370  62370  08/02/1995  İstanbul  Big Cities   IL   3   5   4   5   2
# 74757  74757  08/02/1995  İstanbul  Big Cities   IL   3   5   4   5   2
# 75865  75865  08/02/1995  İstanbul  Big Cities   IL   3   5   4   5   2
# 89385  89385  08/02/1995  İstanbul  Big Cities   IL   3   5   4   5   2
# 99604  99604  08/02/1995  İstanbul  Big Cities   IL   3   5   4   5   2
#
#        ...    P31  P32  P33  P34  P35  P36  P37   Age  isIL  isBig
# 11153  ...      1    5    2    4    4    4    2  7092  True   True
# 62370  ...      1    5    2    4    4    4    2  7092  True   True
# 74757  ...      1    5    2    4    4    4    2  7092  True   True
# 75865  ...      1    5    2    4    4    4    2  7092  True   True
# 89385  ...      1    5    2    4    4    4    2  7092  True   True
# 99604  ...      1    5    2    4    4    4    2  7092  True   True
#
# [6 rows x 45 columns]

# %%
ccols = ['P14','P15','P16','P17','P18','P24','P25','P26','P27','P30','P31','P32','P33','P34','P35','P36','P37']
#T = test.as_matrix(columns=ccols)
#T_xor = np.any(np.concatenate((np.expand_dims(np.all(T==0,1),1), np.expand_dims(np.all(T!=0,1),1)),1),1)

# %%
li_ = test['Age'].values==394
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
T = group[li_centre][0:1][ccols].as_matrix()
T_xor = np.any(np.concatenate((np.expand_dims(np.all(T==0,1),1), np.expand_dims(np.all(T!=0,1),1)),1),1)
print(T_xor)
print(group[li_centre]['Id'].values)
# Out:
# 6
#           Id   Open Date      City  City Group Type  P1  P2  P3  P4  P5  \
# 2134    2134  12/03/2013  İstanbul  Big Cities   FC   4   5   4   5   2
# 13062  13062  12/03/2013  İstanbul  Big Cities   FC   4   5   4   5   2
# 36251  36251  12/03/2013  İstanbul  Big Cities   FC   4   5   4   5   2
# 70575  70575  12/03/2013  İstanbul  Big Cities   FC   4   5   4   5   2
# 86590  86590  12/03/2013  İstanbul  Big Cities   FC   4   5   4   5   2
# 95607  95607  12/03/2013  İstanbul  Big Cities   FC   4   5   4   5   2
#
#        ...    P31  P32  P33  P34  P35  P36  P37  Age   isIL  isBig
# 2134   ...      0    0    0    0    0    0    0  394  False   True
# 13062  ...      0    0    0    0    0    0    0  394  False   True
# 36251  ...      0    0    0    0    0    0    0  394  False   True
# 70575  ...      0    0    0    0    0    0    0  394  False   True
# 86590  ...      0    0    0    0    0    0    0  394  False   True
# 95607  ...      0    0    0    0    0    0    0  394  False   True
#
# [6 rows x 45 columns]
# [ True]
# [ 2134 13062 36251 70575 86590 95607]

# %%
li_ = test['Age'].values==7016
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
T = group[li_centre][0:1][ccols].as_matrix()
T_xor = np.any(np.concatenate((np.expand_dims(np.all(T==0,1),1), np.expand_dims(np.all(T!=0,1),1)),1),1)
print(T_xor)
print(group[li_centre]['Id'].values)
# Out:
# 5
#           Id   Open Date      City  City Group Type  P1  P2  P3  P4  P5  \
# 2141    2141  10/17/1995  İstanbul  Big Cities   IL   4   5   4   5   1
# 41852  41852  10/17/1995  İstanbul  Big Cities   IL   4   5   4   5   1
# 64628  64628  10/17/1995  İstanbul  Big Cities   IL   4   5   4   5   1
# 67454  67454  10/17/1995  İstanbul  Big Cities   IL   4   5   4   5   1
# 94768  94768  10/17/1995  İstanbul  Big Cities   IL   4   5   4   5   1
#
#        ...    P31  P32  P33  P34  P35  P36  P37   Age  isIL  isBig
# 2141   ...      1    4    2    3    2    4    2  7016  True   True
# 41852  ...      1    4    2    3    2    4    2  7016  True   True
# 64628  ...      1    4    2    3    2    4    2  7016  True   True
# 67454  ...      1    4    2    3    2    4    2  7016  True   True
# 94768  ...      1    4    2    3    2    4    2  7016  True   True
#
# [5 rows x 45 columns]
# [ True]
# [ 2141 41852 64628 67454 94768]

# %%
li_ = test['Age'].values==1556
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
T = group[li_centre][0:1][ccols].as_matrix()
T_xor = np.any(np.concatenate((np.expand_dims(np.all(T==0,1),1), np.expand_dims(np.all(T!=0,1),1)),1),1)
print(T_xor)
print(group[li_centre]['Id'].values)
# Out:
# 1
#         Id   Open Date   City City Group Type  P1  P2  P3  P4  P5  ...    P31  \
# 1746  1746  09/28/2010  Bursa      Other   FC   2   3   3   4   2  ...      0
#
#       P32  P33  P34  P35  P36  P37   Age   isIL  isBig
# 1746    0    0    0    0    0    0  1556  False  False
#
# [1 rows x 45 columns]
# [ True]
# [1746]

# %% [markdown]
# ### See if we can manually cluster the ones which didn't work with automated method

# %%
missing_cluster_ages = [a for a in genuinetestmap.keys() if genuinetestmap[a] is None]

# %%
missing_cluster_ages
# Out:
# [468, 538, 540, 605, 754, 805, 944, 1100, 1277, 1675, 2085, 3426, 6876]

# %%
li_ = test['Age'].values==missing_cluster_ages[0]
group = test[li_]
group_centre = {}
for col in test.columns:
    if col=='Id':
        continue
    x,y = uniquehist(group[col].values, uhistdict[col][0])
    y = y/sum(y)
    idx = np.argmax(y - uhistdict[col][1])
    group_centre[col] = uhistdict[col][0][idx]
li_centre = np.ones(len(group),dtype=bool)
for col in test.columns:
    if col=='Id':
        continue
    li_centre = li_centre * (group[col].values == group_centre[col])
print(sum(li_centre))
print(group[li_centre])
T = group[li_centre][0:1][ccols].as_matrix()
T_xor = np.any(np.concatenate((np.expand_dims(np.all(T==0,1),1), np.expand_dims(np.all(T!=0,1),1)),1),1)
print(T_xor)
print(group[li_centre]['Id'].values)
# Out:
# 0
# Empty DataFrame
# Columns: [Id, Open Date, City, City Group, Type, P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15, P16, P17, P18, P19, P20, P21, P22, P23, P24, P25, P26, P27, P28, P29, P30, P31, P32, P33, P34, P35, P36, P37, Age, isIL, isBig]
# Index: []
#
# [0 rows x 45 columns]
# []
# []

# %%
li_ = test['Age'].values==missing_cluster_ages[0]
test[li_]
# Out:
#           Id   Open Date       City  City Group Type  P1   P2   P3   P4  P5  \
# 34        34  09/20/2013  Gaziantep       Other   FC   3  5.0  3.0  4.0   1
